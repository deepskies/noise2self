# %%
import numpy as np

# Set up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from astropy.io import fits

# %%
hdu_list = fits.open('Downloads/imgblock.fits')

image = hdu_list[1].data
model = hdu_list[2].data
resid = hdu_list[3].data

plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(image[0])
plt.subplot(132)
plt.imshow(model)
plt.subplot(133)
plt.imshow(resid)

plt.colorbar()

# %%
hdu_list.info()
# Out:
# Filename: Downloads/imgblock.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       8   (128, 128)   float32
#   1                1 ImageHDU        10   (128, 128, 14)   float32
#   2                1 ImageHDU        43   (128, 128)   float32
#   3                1 ImageHDU         6   (128, 128)   float32
